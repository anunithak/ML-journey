# %%
import pandas as pd

# %%
df=pd.read_csv("covid_cleaned.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Serial Number    231 non-null    int64
#  1   Country          231 non-null    object
#  2   Total Cases      231 non-null    float64
#  3   Total Deaths     231 non-null    float64
#  4   Total Recovered  231 non-null    float64
#  5   Active Cases     212 non-null    float64
#  6   Total Test       213 non-null    float64
#  7   Population       231 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 14.6+ KB

# %%
df.isnull().sum()
# Out:
# Serial Number       0
# Country             0
# Total Cases         0
# Total Deaths        0
# Total Recovered     0
# Active Cases       19
# Total Test         18
# Population          0
# dtype: int64

# %%
##converting the cleaned dataset to JSON and then excel
df.to_json("covid_cleaned.json",orient="records")

# %%
##reading it back to python

df_json=pd.read_json("covid_cleaned.json")

# %%
##now we'll check if the shapes are the same to see if it worked properly

df_json.shape
# Out:
# (231, 8)

# %%
df.shape
# Out:
# (231, 8)

# %%
##converting to excel now

df.to_excel("covid_cleaned.xlsx",index=False)

# %%
##reading it back to python
df_excel=pd.read_excel("covid_cleaned.xlsx")

# %%
df_excel.shape
# Out:
# (231, 8)

# %%
df.shape
# Out:
# (231, 8)
