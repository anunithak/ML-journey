# %%
import pandas as pd

# %%
df=pd.read_csv("cafe_cleaned.csv")

# %%
df.describe()
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  9962.000000     9962.000000  9960.000000
# mean      3.025597        2.947902     8.930924
# std       1.420181        1.279759     6.004475
# min       1.000000        1.000000     1.000000
# 25%       2.000000        2.000000     4.000000
# 50%       3.000000        3.000000     8.000000
# 75%       4.000000        4.000000    12.000000
# max       5.000000        5.000000    25.000000

# %%
df['Price Per Unit'].mean()
# Out:
# 2.94790202770528

# %%
df['Price Per Unit'].min(), df['Price Per Unit'].max()
# Out:
# (1.0, 5.0)

# %%
df['Price Per Unit'].mode()
# Out:
# 0    3.0
# Name: Price Per Unit, dtype: float64

# %%
df['Price Per Unit'].median()
# Out:
# 3.0

# %%
##lets make a comparison table, of mean and median
##first get the numeric columns

cols=["Quantity","Price Per Unit","Total Spent"]

##then make the comparison table, you're giving a dictionary here
comparison= pd.DataFrame({"Mean":df[cols].mean(),"Median":df[cols].median()})

# %%
comparison
# Out:
#                     Mean  Median
# Quantity        3.025597     3.0
# Price Per Unit  2.947902     3.0
# Total Spent     8.930924     8.0
