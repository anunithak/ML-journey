# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %%
##Filtering passengers older than 25 and in 1st class
df[(df["age"]>25)&(df["pclass"]==1)]
# Out:
#      survived  pclass                                               name  \
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5           0       1                            McCarthy, Mr. Timothy J
# 10          1       1                           Bonnell, Miss. Elizabeth
# 20          1       1                       Sloper, Mr. William Thompson
# ..        ...     ...                                                ...
# 693         0       1               Roebling, Mr. Washington Augustus II
# 696         1       1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 697         0       1                           Carlsson, Mr. Frans Olof
# 703         1       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 712         1       1                              Behr, Mr. Karl Howell
#
#         sex   age     fare  sibsp  parch
# 1    female  38.0  71.2833      1      0
# ...

# %%
##Selecting only specific columns
df[["name","age","pclass","survived"]]
# Out:
#                                                   name   age  pclass  survived
# 0                              Braund, Mr. Owen Harris  22.0       3         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1         1
# 2                               Heikkinen, Miss. Laina  26.0       3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1         1
# 4                             Allen, Mr. William Henry  35.0       3         0
# ..                                                 ...   ...     ...       ...
# 709               Rice, Mrs. William (Margaret Norton)  39.0       3         0
# 710                              Montvila, Rev. Juozas  27.0       2         0
# 711                       Graham, Miss. Margaret Edith  19.0       1         1
# 712                              Behr, Mr. Karl Howell  26.0       1         1
# 713                                Dooley, Mr. Patrick  32.0       3         0
#
# [714 rows x 4 columns]

# %%
##accessing rows 5 to 15
df.iloc[5:16]
# Out:
#     survived  pclass                                               name  \
# 5          0       1                            McCarthy, Mr. Timothy J
# 6          0       3                     Palsson, Master. Gosta Leonard
# 7          1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 8          1       2                Nasser, Mrs. Nicholas (Adele Achem)
# 9          1       3                    Sandstrom, Miss. Marguerite Rut
# 10         1       1                           Bonnell, Miss. Elizabeth
# 11         0       3                     Saundercock, Mr. William Henry
# 12         0       3                        Andersson, Mr. Anders Johan
# 13         0       3               Vestrom, Miss. Hulda Amanda Adolfina
# 14         1       2                   Hewlett, Mrs. (Mary D Kingcome)
# 15         0       3                               Rice, Master. Eugene
#
#        sex   age     fare  sibsp  parch
# 5     male  54.0  51.8625      0      0
# ...
